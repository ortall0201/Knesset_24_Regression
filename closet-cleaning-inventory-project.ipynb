# %% [markdown]
# Mini Project: MySQL CRUD Operations Practice
#
# Based on "The Ultimate MySQL Bootcamp: Go from SQL Beginner to Expert" by Colt Steele

# %% [markdown]
# # 1. Introduction

# %% [markdown]
# This mini project was created as part of my hands-on practice while completing the Udemy course "The Ultimate MySQL Bootcamp: Go from SQL Beginner to Expert" by Colt Steele.
#
# The goal of this project was to design and implement a relational database using MySQL to manage a closet inventory system, applying the CRUD methodology (Create, Read, Update, Delete). The project demonstrates:
#
# Database creation
# Table design
# Data insertion
# Querying with SELECT and WHERE
# Updating data
# Deleting data
# Dropping the table
# Everything was executed in MySQL CLI, simulating a real database management workflow.

# %% [markdown]
# # Step 1: Create the Database

# %% [markdown]
# I started by creating a dedicated database for this project, called shirts_db.

# %% [markdown]
# CREATE DATABASE shirts_db;
# USE shirts_db;

# %% [markdown]
# # Step 2: Create the shirts Table

# %% [markdown]
# The shirts table stores information about individual clothing items, with relevant details like type, color, size, and when they were last worn.

# %% [markdown]
# ![image.png](attachment:a44f2acb-ed30-4286-b3f6-25714b0379ee.png)

# %% [markdown]
# ![image.png](attachment:8a53db81-845e-43b6-8049-e06faf69e727.png)

# %% [markdown]
# #  Step 3: Insert Data into the Table

# %% [markdown]
# Here are example entries representing different shirts in my closet.

# %% [markdown]
# ![image.png](attachment:39bdfa3b-a46a-4466-bc5a-92835f6d2038.png)

# %% [markdown]
# # Step 4: Retrieve Data (SELECT Queries)

# %% [markdown]
# I used SELECT queries to explore the data and apply conditions.

# %% [markdown]
# View the entire inventory:

# %% [markdown]
# ![image.png](attachment:e309ab2a-6e88-44d3-86ee-0c2e0042dcfd.png)

# %% [markdown]
# Adding a new row to the shirts table:

# %% [markdown]
# ![image.png](attachment:9e18ffb5-7df3-406c-b09a-8ff94d3e2ed8.png)

# %% [markdown]
# Selecting all shirts but only outputing 2 specific columns (article, color):

# %% [markdown]
# ![image.png](attachment:be094d45-59ce-43bc-9735-d26f8b8d06af.png)

# %% [markdown]
# # Step 5: Update Records

# %% [markdown]
# Updated only polo shirts shirt_size to be 'L'. First verified what is the shirt_size by selecting and using the WHERE clause and only then updated and verified that mission accomplished.

# %% [markdown]
# ![image.png](attachment:0f0411ff-07d9-4bc1-af0a-a3fc264cc3e3.png)

# %% [markdown]
# # Step 6: Delete Records

# %% [markdown]
# When I donated or discarded shirts, I deleted them from the database.

# %% [markdown]
# ![image.png](attachment:522bbe73-c3a5-4496-b2aa-805c3de3a99a.png)

# %% [markdown]
# Clear the entire closet:

# %% [markdown]
# ![image.png](attachment:734da042-8817-4c36-a4de-21a2cb1fd6e7.png)

# %% [markdown]
# # Step 7: Drop the Table
#
# (no going back from this, it will be gone gone...bye bye shirts)

# %% [markdown]
# ![image.png](attachment:ea122571-99c4-4365-824c-ea78d4842ba5.png)

# %% [markdown]
# # Conclusion

# %% [markdown]
# This mini-project was part of my practical learning in the Udemy MySQL Bootcamp by Colt Steele. It allowed me to strengthen my understanding of SQL CRUD operations, table design, and data manipulation in MySQL, all within a simple and relatable use case.

# %% [markdown]
# # GitHub Repository

# %% [markdown]
# https://github.com/ortall0201/Closet-Cleaning-Inventory-Project-using-SQL/blob/main/Cleaning_closet.sql
